# %% [markdown]
# ## API 활용

# %% [markdown]
# terminal에서
#
# `pip install requests`
#
# 명령어를 통해 requests 모듈을 다운받습니다

# %% [markdown]
# ### 자원 조회
# 특정 데이터를 가져오거나 전체 목록을 불러올 때 사용한다.

# %%
import requests
from pprint import pprint

# 단일 리소스 조회
url = "https://jsonplaceholder.typicode.com/posts/11"
response = requests.get(url)
print(response)
pprint(response.json())

# 전체 목록 조회
list_url = "https://jsonplaceholder.typicode.com/posts"
list_response = requests.get(list_url)
print("전체 게시글 개수:", len(list_response.json()))
# Out:
# <Response [200]>
# {'body': 'delectus reiciendis molestiae occaecati non minima eveniet qui '
#          'voluptatibus\n'
#          'accusamus in eum beatae sit\n'
#          'vel qui neque voluptates ut commodi qui incidunt\n'
#          'ut animi commodi',
#  'id': 11,
#  'title': 'et ea vero quia laudantium autem',
#  'userId': 2}
# 전체 게시글 개수: 100

# %% [markdown]
# ### 자원 생성
# 새로운 데이터를 서버에 등록한다. 데이터는 JSON 형식으로 전달된다.

# %%
url = "https://jsonplaceholder.typicode.com/posts"

new_data = {
    "title": "새로운 제목",
    "body": "새로운 내용",
    "userId": 1
}

response = requests.post(url, json=new_data)
print("생성 성공 상태 코드:", response.status_code)
print("응답 데이터:", response.json())
# Out:
# 생성 성공 상태 코드: 201
# 응답 데이터: {'title': '새로운 제목', 'body': '새로운 내용', 'userId': 1, 'id': 101}

# %% [markdown]
# ### 자원 수정
# 데이터의 일부를 변경을 요청한다.

# %%
url = "https://jsonplaceholder.typicode.com/posts/1"

# 일부 수정
patch_data = {"title": "수정된 제목"}
patch_response = requests.patch(url, json=patch_data)
print("수정 결과:", patch_response.json())
# Out:
# 수정 결과: {'userId': 1, 'id': 1, 'title': '수정된 제목', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}
# 삭제 성공 상태 코드: 200

# %% [markdown]
# ### 자원 삭제
# 데이터 삭제를 요청한다.

# %%
url = "https://jsonplaceholder.typicode.com/posts/1"


# 삭제
delete_response = requests.delete(url)
print("삭제 성공 상태 코드:", delete_response.status_code)
# Out:
# 삭제 성공 상태 코드: 200

# %% [markdown]
# ### 필터링
# 보조적인 조건을 추가하여 정보를 가져온다.

# %%
# 쿼리 매개변수를 활용한 필터링
query_url = "https://jsonplaceholder.typicode.com/posts"

params = {"userId": 10}

filter_response = requests.get(query_url, params=params)
print(len(filter_response.json()))

pprint(filter_response.json())

# %% [markdown]
# ### 중첩 리소스 조회
# 특정 자원에 종속된 정보를 가져온다.

# %%
# 중첩 리소스 조회
nested_url = "https://jsonplaceholder.typicode.com/posts/1/comments"
nested_response = requests.get(nested_url)
print("1번 게시글의 첫 번째 댓글:", nested_response.json()[0])
# Out:
# 1번 게시글의 첫 번째 댓글: {'postId': 1, 'id': 1, 'name': 'id labore ex et quam laborum', 'email': 'Eliseo@gardner.biz', 'body': 'laudantium enim quasi est quidem magnam voluptate ipsam eos\ntempora quo necessitatibus\ndolor quam autem quasi\nreiciendis et nam sapiente accusantium'}

# %%
import requests
from pprint import pprint

posts_url = "https://jsonplaceholder.typicode.com/posts"
comments_url = "https://jsonplaceholder.typicode.com/posts/1/comments"

new_data = {
    "title": "제 전투력은 53만",
    "body": "프리더의 아버지는 콜드대왕이다. 트랭크스한테 반갈죽 당함",
    "userId": 10
}

post_response = requests.post(posts_url, json=new_data)

print("생성 성공 상태 코드:", post_response.status_code)

print("응답 데이터:", post_response.json())


patch_url = "https://jsonplaceholder.typicode.com/posts/96"
patch_data = {
    "title" : "슬램덩크 학계의 점심",
    "body": "산왕이 북산한테 진 이유는 빡빡이여서다"
    }

patch_response = requests.patch(patch_url, json=patch_data)

print(response.text)

pprint(type(patch_response))
print("수정 결과:", patch_response.json())
# Out:
# 생성 성공 상태 코드: 201
# 응답 데이터: {'title': '제 전투력은 53만', 'body': '프리더의 아버지는 콜드대왕이다. 트랭크스한테 반갈죽 당함', 'userId': 10, 'id': 101}
# {
#   "title": "제 전투력은 53만",
#   "body": "프리더의 아버지는 콜드대왕이다. 트랭크스한테 반갈죽 당함",
#   "userId": 10,
#   "id": 101
# }
# <class 'requests.models.Response'>
# 수정 결과: {'userId': 10, 'id': 96, 'title': '슬램덩크 학계의 점심', 'body': '산왕이 북산한테 진 이유는 빡빡이여서다'}

# %%
import requests

url = "https://api.themoviedb.org/3/authentication"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIzNWUxYjgxNjkxOGMzZWUwMzAwMmY3NjIyNmQxYjAwNCIsIm5iZiI6MTc2ODUzNjY1NC4yODEsInN1YiI6IjY5NjliYTRlZDMwNDc3OTE1ZTk0YmEzZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Aizd2zERyIK8yBl184D8rAUTIVTCJVQWfJlj-W-pNfs"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"success":true}
