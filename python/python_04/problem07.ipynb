# %% [markdown]
# ### 문제 1
# API로 전달받은 게시글 데이터입니다. `status`가 'published'인 게시글들만 필터링하여, 해당 게시글들의 `view_count` 총합을 구하세요.

# %%
posts = [
    {'title': '첫 번째 글', 'status': 'published', 'view_count': 120},
    {'title': '두 번째 글', 'status': 'draft', 'view_count': 0},
    {'title': '세 번째 글', 'status': 'published', 'view_count': 350},
    {'title': '네 번째 글', 'status': 'deleted', 'view_count': 10}
]

total = 0

for post in posts:
    score = post.get("view_count")
    if post.get("status") == "published":
        total += score
print(total)
# Out:
# 470

# %% [markdown]
# ### 문제 2
# 유저 권한 시스템 로직입니다. 아래 규칙에 따라 접근 가능 여부(`True`/`False`)를 판단하여 결과를 적절한 형태로 만드세요.
# 1. `role`이 'admin'이면 점수와 상관없이 `True`
# 2. `role`이 'user'이고 `score`가 80점 이상이면 `True`
# 3. 그 외(guest 등)는 모두 `False`

# %%
users = [
    {'name': 'Kim', 'info': {'role': 'admin', 'score': 50}},
    {'name': 'Lee', 'info': {'role': 'user', 'score': 85}},
    {'name': 'Park', 'info': {'role': 'user', 'score': 70}},
    {'name': 'Choi', 'info': {'role': 'guest', 'score': 100}}
]
access_results = []
access_results_dict = {}

# 코드를 작성하세요
for user in users:
    role = user.get("info").get("role")
    # print(role)
    if role == 'admin' or role == 'user':
        access_results.append(True)
    else: 
        access_results.append(False)
        
print(f"접근 권한 결과: {access_results}")

for user in users:
    name = user.get("name")
    role = user.get("info").get("role")
    
    access_status = False
    
    if role == 'admin' or role == 'user':
        access_status = True
        access_results_dict[name] = access_status
    else:
        access_results_dict[name] = access_status
            
    print(f"접근 권한 결과 dict: {access_results_dict}")
# Out:
# 접근 권한 결과: [True, True, True, False]
# 접근 권한 결과 dict: {'Kim': True}
# 접근 권한 결과 dict: {'Kim': True, 'Lee': True}
# 접근 권한 결과 dict: {'Kim': True, 'Lee': True, 'Park': True}
# 접근 권한 결과 dict: {'Kim': True, 'Lee': True, 'Park': True, 'Choi': False}

# %% [markdown]
# ### 문제 3
# 쇼핑몰의 카테고리별 상품 데이터입니다. 전체 상품 중 가격(`price`)이 50,000원 이상인 상품의 이름(`name`)만 모아서 하나의 리스트로 만드세요.

# %%
store_data = {
    "electronics": [
        {"name": "키보드", "price": 45000},
        {"name": "모니터", "price": 200000}
    ],
    "fashion": [
        {"name": "티셔츠", "price": 20000},
        {"name": "청바지", "price": 60000},
        {"name": "재킷", "price": 120000}
    ],
    "furniture": [
        {"name": "의자", "price": 200000},
        {"name": "책상", "price": 600000},
        {"name": "책장", "price": 1200000}
    ]
}

expensive_product = []

for categoryitem in store_data.values():   
    print(categoryitem)
    
    # for item in category_items:             
    #     if item["price"] >= 50000:
            # result.append(item["name"])

# print(result)
    
for category, products in store_data.items():
    # print(f"카테고리 ={category}, 상품?={product}")
    
    for product in products:
        # print(product)
        product_price = product.get("price")
        # print(product_price)
        
        if product_price >= 50000:
            # print(product)
            name = product.get("name")
            print(name)
            expensive_product.append(name)
            
print(expensive_product)
# Out:
# [{'name': '키보드', 'price': 45000}, {'name': '모니터', 'price': 200000}]
# [{'name': '티셔츠', 'price': 20000}, {'name': '청바지', 'price': 60000}, {'name': '재킷', 'price': 120000}]
# [{'name': '의자', 'price': 200000}, {'name': '책상', 'price': 600000}, {'name': '책장', 'price': 1200000}]
# 모니터
# 청바지
# 재킷
# 의자
# 책상
# 책장
# ['모니터', '청바지', '재킷', '의자', '책상', '책장']

# %% [markdown]
# ### 문제 4
# 주문 내역 데이터입니다. 각 주문 별로 'items' 리스트가 들어있습니다. 전체 주문을 통틀어 '품절(out_of_stock)' 상태가 포함된 주문의 `order_id` 리스트를 구하세요. 또한 품절 상태인 items의 name에 대한 list를 구하세요.

# %%
orders = [
    {
        "order_id": "ORD-001",
        "items": [
            {"name": "사과", "status": "in_stock"},
            {"name": "배", "status": "in_stock"}
        ]
    },
    {
        "order_id": "ORD-002",
        "items": [
            {"name": "포도", "status": "out_of_stock"},
            {"name": "딸기", "status": "in_stock"}
        ]
    },
    {
        "order_id": "ORD-003",
        "items": [
            {"name": "수박", "status": "out_of_stock"}
        ]
    },
    {
        "order_id": "ORD-004",
        "items": [
            {"name": "참외", "status": "out_of_stock"},
            {"name": "멜론", "status": "out_of_stock"}
        ]
    },
    {
        "order_id": "ORD-005",
        "items": [
            {"name": "망고", "status": "out_of_stock"},
            {"name": "토마토", "status": "in_stock"},
            {"name": "호두", "status": "out_of_stock"}
        ]
    },
]

problematic_orders = []
problematic_orders_name = []

for order in orders:
    order_id = order.get("order_id")
    items = order.get("items")
    sold_out = False
    
    for item in items:
        status = item.get("status")
        name = item.get("name")
    
        if status == "out_of_stock":
            problematic_orders_name.append(name)
            sold_out = True

            print(order_id)
            print(item)
            print(name)
    print(sold_out)

    if sold_out:
        problematic_orders.append(order_id)

            
# 코드를 작성하세요
print(f"품절 포함 주문 ID: {problematic_orders}")
print(f"품절된 제품들 {problematic_orders_name}")
# Out:
# False
# ORD-002
# {'name': '포도', 'status': 'out_of_stock'}
# 포도
# True
# ORD-003
# {'name': '수박', 'status': 'out_of_stock'}
# 수박
# True
# ORD-004
# {'name': '참외', 'status': 'out_of_stock'}
# 참외
# ORD-004
# {'name': '멜론', 'status': 'out_of_stock'}
# 멜론
# True
# ORD-005
# {'name': '망고', 'status': 'out_of_stock'}
# 망고
# ORD-005
# {'name': '호두', 'status': 'out_of_stock'}
# 호두
# True
# 품절 포함 주문 ID: ['ORD-002', 'ORD-003', 'ORD-004', 'ORD-005']
# 품절된 제품들 ['포도', '수박', '참외', '멜론', '망고', '호두']
